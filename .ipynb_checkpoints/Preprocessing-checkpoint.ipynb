# %% [markdown]
# ## Dataset:
#
# File:                     Multi-Modal MRI Data/person
#
# File Format:          nii.gz
#
# Image Shape:       240(Slide Width) × 240(Slide Height) × 155(Number of Slide) × 4(Multi-mode)
#
# Image Mode:        4 (Multi-mode)

# %% [markdown]
# # Multimodal data
# channel 0: FLAIR
# channel 1: T1
# channel 2: T1c
# channel 3: T2

# %% [markdown]
# ## Labels
#
# channel 0: background \
# channel 1: necrotic and non-enhancing tumor \
# channel 2: edema \
# channel 3: enhancing tumor
#
# will change the intensity of the mask to different values to create the binary class problem \
# C1 = 50     # Necrotic and Non-enhancing Tumor \
# C2 = 100    # Edema \
# C3 = 150    # Enhancing Tumor

# %%
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib
import torch
import glob
import os, sys, time
import h5py
import random
from torch.utils import data
import helpers
from pathlib import Path
import cv2
import shutil

# %%
def getfilename(rootdir,volume):
    filename = rootdir+f'volume_{int(volume)}_slice*.h5'
    #print(filename)
    file = glob.glob(filename)
    
    return file

# %%
# Out:
# 130

# %%
rootdir = '/home/jay/Documents/courses/Aicourse/Brats/BraTS2020_training_data/content/data/'
volume = []
allfilename = glob.glob(rootdir+'/*.h5')
for i in range(len(allfilename)):
    name = allfilename[i].split('volume_')[1].split('_')[0]
    if name not in volume:
        volume.append(name)

# %%
# Out:
# 39990

# %%
rootdir = '/home/jay/Documents/courses/Aicourse/Brats/BraTS2020_training_data/content/data/'
outputdir = '/home/jay/Documents/courses/Aicourse/Brats/'
try:
    shutil.rmtree(outputdir +'/train/')
except:
    pass

try:
    shutil.rmtree(outputdir +'/test/')
except:
    pass

try:
    shutil.rmtree(outputdir +'/validation/')
except:
    pass

try:
    os.makedirs(outputdir +'/train/')
except:
    pass
try:   
    os.makedirs(outputdir +'/test/')
except:
    pass
try:    
    os.makedirs(outputdir +'/validation/')
except:
    pass

np.random.seed(20894573)
np.random.shuffle(volume)

train_size = 0.8
validation_size = 0.1


train, validate, test=np.split(np.array(volume), [int(train_size*len(volume)), int((1-validation_size)*len(volume))])

print(f'Train: {np.shape(train)[0]}, Valid: {np.shape(validate)[0]}, Test: {np.shape(test)[0]}')
trainfile=0
validfiles=0
testfiles=0

for i in range(len(train)):
    nametrain = getfilename(rootdir, train[i])
    for name in nametrain:
        #print(name)
        shutil.copy(name, outputdir +'/train/')
        trainfile = trainfile+1
        
for i in range(len(validate)):
    namevalid = getfilename(rootdir, validate[i])
    for name in namevalid:
        shutil.copy(name, outputdir +'/validation/')
        validfiles= validfiles+ 1
        
for i in range(len(test)):
    nametest = getfilename(rootdir, test[i])
    for name in nametest:
        shutil.copy(name, outputdir +'/test/')
        testfiles =  testfiles+1
        
print(f'Train: {trainfile}, Valid: {validfiles}, Test: {testfiles}')
# Out:
# Train: 295, Valid: 37, Test: 37
# Train: 45725, Valid: 5735, Test: 5735

# %%
np.shape(train)
# Out:
# (0,)

# %%
# np.shape(test)
# Out:
# (47,)

# %%
# #Preprocessing Binary multiscale mask and normalize the intensity

# def hd5normalize_img(img_path, output_root):
#     img_name = (img_path.split('/')[-1]).split('.')[0]
#     print(img_path)
    
#     output_path = os.path.join(output_root, img_name)
#     try:
#         os.makedirs(output_root)
#     except:
#         pass
#     #try:
#    #     os.makedirs(output_path)
#    # except:
#    #     pass
#     img = h5py.File(img_path,'r')['image']
#     msk = h5py.File(img_path,'r')['mask']
    
#     image = np.zeros(np.shape(img))
#     mask = np.zeros(np.shape(msk))
    
#     image[:,:,0] = cv2.normalize(img[:,:,0],None, norm_type=cv2.NORM_MINMAX)
#     image[:,:,1] = cv2.normalize(img[:,:,1],None, norm_type=cv2.NORM_MINMAX)
#     image[:,:,2] = cv2.normalize(img[:,:,2],None, norm_type=cv2.NORM_MINMAX)
#     image[:,:,3] = cv2.normalize(img[:,:,3],None, norm_type=cv2.NORM_MINMAX)
    
    
    
#     mask[:,:,0] = msk[:,:,0]*50
#     mask[:,:,1] = msk[:,:,1]*100
#     mask[:,:,2] = msk[:,:,2]*150
#     maskflat = mask[:,:,0]+mask[:,:,1]+mask[:,:,2]
    
#     filename = os.path.join(output_root, img_name+'.h5')
#     hf = h5py.File(filename, 'w')
#     hf.create_dataset('image', data=image)
#     hf.create_dataset('mask', data=maskflat)

# %%
# import h5py
# import helpers
# import numpy as np
# from pathlib import Path
# import torch
# from torch.utils import data

# class HDF5Dataset(data.Dataset):
#     """Represents an abstract HDF5 dataset.
    
#     Input params:
#         file_path: Path to the folder containing the dataset (one or multiple HDF5 files).
#         recursive: If True, searches for h5 files in subdirectories.
#         load_data: If True, loads all the data immediately into RAM. Use this if
#             the dataset is fits into memory. Otherwise, leave this at false and 
#             the data will load lazily.
#         data_cache_size: Number of HDF5 files that can be cached in the cache (default=3).
#         transform: PyTorch transform to apply to every data instance (default=None).
#     """
#     def __init__(self, file_path, recursive, load_data, data_cache_size=3, transform=None):
#         super().__init__()
#         self.data_info = []
#         self.data_cache = {}
#         self.data_cache_size = data_cache_size
#         self.transform = transform

#         # Search for all h5 files
#         p = Path(file_path)
#         assert(p.is_dir())
#         if recursive:
#             files = sorted(p.glob('**/*.h5'))
#         else:
#             files = sorted(p.glob('*.h5'))
#         if len(files) < 1:
#             raise RuntimeError('No hdf5 datasets found')

#         for h5dataset_fp in files:
#             self._add_data_infos(str(h5dataset_fp.resolve()), load_data)
            
#     def __getitem__(self, index):
#         # get data
#         x = self.get_data("image", index)
#         if self.transform:
#             x = self.transform(x)
#         else:
#             x = torch.from_numpy(x)

#         # get label
#         y = self.get_data("mask", index)
#         y = torch.from_numpy(y)
#         return (x, y)

#     def __len__(self):
#         return len(self.get_data_infos('image'))
    
#     def _add_data_infos(self, file_path, load_data):
#         with h5py.File(file_path) as h5_file:
#             # Walk through all groups, extracting datasets
        
#                 for dname, ds in h5_file.items():
#                     # if data is not loaded its cache index is -1
#                     idx = -1
#                     if load_data:
#                         # add data to the data cache
                        
#                         if dname == 'mask':
#                             mask = np.zeros(np.shape(ds[()]))
#                             mask[:,:,0] = ds[()][:,:,0]*50
#                             mask[:,:,1] = ds[()][:,:,1]*100
#                             mask[:,:,2] = ds[()][:,:,2]*150
#                             maskflat = mask[:,:,0]+mask[:,:,1]+mask[:,:,2]
#                             idex = self._add_to_cache(maskflat, file_path)
                            
#                         else:
#                             image = np.zeros(np.shape(ds[()]))
#                             image[:,:,0] = cv2.normalize(ds[()][:,:,0],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,1] = cv2.normalize(ds[()][:,:,1],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,2] = cv2.normalize(ds[()][:,:,2],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,3] = cv2.normalize(ds[()][:,:,3],None, norm_type=cv2.NORM_MINMAX)
#                             idx = self._add_to_cache(image, file_path)
                    
#                     # type is derived from the name of the dataset; we expect the dataset
#                     # name to have a name such as 'data' or 'label' to identify its type
#                     # we also store the shape of the data in case we need it
#                     self.data_info.append({'file_path': file_path, 'type': dname, 'shape': np.shape(ds[()]), 'cache_idx': idx})

#     def _load_data(self, file_path):
#         """Load data to the cache given the file
#         path and update the cache index in the
#         data_info structure.
#         """
#         with h5py.File(file_path) as h5_file:
            
#                 for dname, ds in h5_file.items():
#                     # add data to the data cache and retrieve
#                     # the cache index
#                     if dname == 'mask':
#                             mask = np.zeros(np.shape(ds[()]))
#                             mask[:,:,0] = ds[()][:,:,0]*50
#                             mask[:,:,1] = ds[()][:,:,1]*100
#                             mask[:,:,2] = ds[()][:,:,2]*150
#                             maskflat = mask[:,:,0]+mask[:,:,1]+mask[:,:,2]
#                             idex = self._add_to_cache(maskflat, file_path)
                            
#                     else:
#                             image = np.zeros(np.shape(ds[()]))
#                             image[:,:,0] = cv2.normalize(ds[()][:,:,0],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,1] = cv2.normalize(ds[()][:,:,1],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,2] = cv2.normalize(ds[()][:,:,2],None, norm_type=cv2.NORM_MINMAX)
#                             image[:,:,3] = cv2.normalize(ds[()][:,:,3],None, norm_type=cv2.NORM_MINMAX)
#                             idx = self._add_to_cache(image, file_path)
                            
#                     # find the beginning index of the hdf5 file we are looking for
#                     file_idx = next(i for i,v in enumerate(self.data_info) if v['file_path'] == file_path)

#                     # the data info should have the same index since we loaded it in the same way
#                     self.data_info[file_idx + idx]['cache_idx'] = idx

#         # remove an element from data cache if size was exceeded
#         if len(self.data_cache) > self.data_cache_size:
#             # remove one item from the cache at random
#             removal_keys = list(self.data_cache)
#             removal_keys.remove(file_path)
#             self.data_cache.pop(removal_keys[0])
#             # remove invalid cache_idx
            
#             self.data_info = [{'file_path': di['file_path'], 'type': di['type'], 'shape': di['shape'], 'cache_idx': -1} if di['file_path'] == removal_keys[0] else di for di in self.data_info]

#     def _add_to_cache(self, data, file_path):
#         """Adds data to the cache and returns its index. There is one cache
#         list for every file_path, containing all datasets in that file.
#         """
#         if file_path not in self.data_cache:
#             self.data_cache[file_path] = [data]
#         else:
#             self.data_cache[file_path].append(data)
#         #print(file_path)
#         return len(self.data_cache[file_path]) - 1

#     def get_data_infos(self, type):
#         """Get data infos belonging to a certain type of data.
#         """
#         data_info_type = [di for di in self.data_info if di['type'] == type]
#         return data_info_type

#     def get_data(self, type, i):
#         """Call this function anytime you want to access a chunk of data from the
#             dataset. This will make sure that the data is loaded in case it is
#             not part of the data cache.
#         """
#         fp = self.get_data_infos(type)[i]['file_path']
#         if fp not in self.data_cache:
#             self._load_data(fp)
        
#         # get new cache_idx assigned by _load_data_info
#         cache_idx = self.get_data_infos(type)[i]['cache_idx']
#         return self.data_cache[fp][cache_idx]

# %%
# # Get all the h5 file and normalize the images and rescale the mask
# %timeit
# hdfiles = glob.glob('/home/jay/Downloads/Brats/BraTS2020_training_data/content/data/*.h5')
# output_folder = '/mnt/Brats/BraTS2020_norm_data/'

# for i in range(len(hdfiles)):
#     hd5normalize_img(hdfiles[i],output_folder)

# %%
# testset = HDF5Dataset('/home/jay/Downloads/Brats/BraTS2020_subtest/',False,False)
# dataset_size = np.shape(testset.data_info)[0]/2

# %%
# train_size = int(0.8 * dataset_size)
# validation_size = int(0.1 * dataset_size)
# test_size = int(dataset_size - train_size - validation_size)
# train_dataset, validation_dataset, test_dataset = torch.utils.data.random_split(testset, [train_size, validation_size, test_size])

# %%
# train_dataset.dataset

# %%
# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64)
# validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size=64)

# %%
# train_dataset.dataset

# %%
# for X, y in train_dataset:
#     print("Shape of X [N, C, H, W]: ", X.shape)
#     print("Shape of y: ", y.shape, y.dtype)
# Out:
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64
# Shape of X [N, C, H, W]:  torch.Size([240, 240, 4])
# Shape of y:  torch.Size([240, 240]) torch.float64

# %%
image1 = example_dt['image']

# %%
# Load h5py file
example_dt = h5py.File('/home/jay/Downloads/Brats/BraTS2020_training_data/content/data/volume_100_slice_75.h5','r')

# %%
image = image1
j = (image- np.nanmean(image, axis=(0,1)))/np.nanstd(image,axis=(0,1))

# %%
np.uint8
# Out:
# numpy.uint8

# %%
plt.imshow((image1[:,:,0]/np.max(image1[:,:,0]))*255)
print(np.unique(j))
plt.colorbar()
# Out:
# [-0.56715587 -0.55306116 -0.5263712  ...  7.12973684  7.25393912
#   7.53783004]

# %%
# plt.imshow(image[:,:,3])
# plt.colorbar()

# %%
from pathlib import Path

# %%
p = Path('/home/jay/Downloads/Brats/train')

# %%
assert(p.is_dir())

# %%
files = sorted(p.glob('*.h5'))

# %%
files = sorted(p.glob('**/*.h5'))

# %%
files
# Out:
# [PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_0.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_1.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_10.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_100.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_101.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_102.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_104.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_105.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_106.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_107.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_108.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_109.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_11.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_110.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_111.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_112.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_113.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_114.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_116.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_117.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_118.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_12.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_120.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_121.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_122.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_123.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_124.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_126.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_127.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice_128.h5'),
#  PosixPath('/home/jay/Downloads/Brats/train/volume_1_slice